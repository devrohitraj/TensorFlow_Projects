# %% [markdown]
# # Palo Alto POI and Clustering

# %% [markdown]
# I am going to use basic nltk packages for stopwords, tokens, vectorizer, Stemmer and Lemmatization. Scikit-learn for Vectorizer, Normalizer, metrices and clustering algorithm(KMean)

# %%
# importing all necessary packages
from __future__ import print_function
import matplotlib.pyplot as plt
from matplotlib import style
style.use("ggplot")

import numpy as np
import pandas as pd

import string
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
stemmer = SnowballStemmer('english')
from nltk.corpus import stopwords

import urllib.request
from bs4 import BeautifulSoup
user_agent = 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'
headers={'User-Agent':user_agent,}

from sklearn.decomposition import TruncatedSVD
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Normalizer
from sklearn import metrics
from sklearn.cluster import KMeans, MiniBatchKMeans

# %% [markdown]
# Scrapping the data from few Travel related websites using BeautifulSoup and making ready for preprocessing

# %%
'''
# Scrapping data from few pages using BeautifulSoup
'''

# method for scrapping the data
def scrap_data(url):
    request=urllib.request.Request(url,None,headers) #The assembled request
    response = urllib.request.urlopen(request).read()

    soup = BeautifulSoup(response, "html.parser")

    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()    # rip it out

    # get text
    text = soup.get_text()

    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)

    return text

# %% [markdown]
# Code to read all urls and save to local file for further usages.

# %%
# scrap data and save to file
url = ['https://wikitravel.org/en/Palo_Alto']
urls = ['https://www.tripadvisor.in/Attractions-g32849-Activities-Palo_Alto_California.html', 'https://wikitravel.org/en/Palo_Alto', 'https://en.wikivoyage.org/wiki/Palo_Alto', 'https://en.wikipedia.org/wiki/List_of_attractions_in_Silicon_Valley','http://vacationidea.com/california/best-things-to-do-in-palo-alto-ca.html', 'https://wikitravel.org/en/Palo_Alto']
data = ""
for each_url in urls:
    data += scrap_data(each_url)
with open("data.txt", "w", encoding="utf-8") as text_file:
    text_file.write(data)

# %% [markdown]
# methods to read data from files and clean the recieved data. Removed punctuation, whitespaces, numeric data, and stopwords. Also have applied stemming on the tokens. Any tokens of one length is removed.

# %%
from sklearn.datasets import fetch_20newsgroups
categories = [
    'alt.atheism',
    'talk.religion.misc',
    'comp.graphics',
    'sci.space',
]
dataset = fetch_20newsgroups(subset='all', categories=categories, shuffle=True, random_state=42)
print("%d documents" % len(dataset.data))
# Out:
# 3387 documents

# %%
lemmatizer = WordNetLemmatizer()

import re

EMAIL_REGEX = re.compile(r"[^@]+@[^@]+\.[^@]+")
news_data = dataset.data

# load data from file
def load_doc(filename):
    file = open(filename, 'r', encoding="utf-8")
    text = file.read()
    file.close()
    return text

# clean data and stem it
def clean_doc(data):
    tokens = data.lower().split()
    # remove punctuation
    table = str.maketrans('', '', string.punctuation)
    tokens = [w.translate(table) for w in tokens]
    # remove all numeric data
    tokens = [word for word in tokens if word.isalpha()]
    # Check for email
    tokens = [word for word in tokens if not EMAIL_REGEX.match(word)]
    # remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [w for w in tokens if not w in stop_words]
    # remove words with length 1
    tokens = [w for w in tokens if len(w) > 1]
    # remove hyperlinks
    tokens = [w for w in tokens if not "www" in w]
    # remove words that is not english
    tokens = [w for w in tokens if wordnet.synsets(w)]
    #stemmed_tokens = [stemmer.stem(word) for word in tokens]
    # lemmatizing the words
    lemma_tokens = [lemmatizer.lemmatize(word) for word in tokens]
    # removing duplicates words
    tokens = list(set(lemma_tokens))
    return tokens

filename = 'data.txt'
text = load_doc(filename)
tokens = clean_doc(text)
print(tokens)
# Out:
# ['ridge', 'bullet', 'served', 'pedigree', 'crowning', 'artisan', 'flaky', 'read', 'louisville', 'produced', 'irrigation', 'special', 'bird', 'intended', 'possible', 'arthur', 'also', 'huntsville', 'consists', 'resort', 'coming', 'falter', 'family', 'californian', 'project', 'referred', 'padre', 'office', 'listed', 'rare', 'bruno', 'pizza', 'norway', 'concentrate', 'planetarium', 'try', 'major', 'jean', 'emphasis', 'every', 'cardinal', 'use', 'transport', 'drive', 'monte', 'understated', 'asian', 'distinctive', 'become', 'palace', 'peter', 'moving', 'inspired', 'needed', 'tidal', 'six', 'tap', 'across', 'augustine', 'accented', 'offered', 'complimentary', 'connect', 'black', 'bruges', 'duluth', 'fargo', 'elope', 'camden', 'sharing', 'meat', 'appears', 'privacy', 'preparation', 'naples', 'prescott', 'dormitory', 'moment', 'foothill', 'hexagonal', 'sport', 'garden', 'expectation', 'pet', 'dc', 'nh', 'created', 'seeing', 'dayton', 'size', 'athletic', 'operating', 'missouri', 'mini', 'check', 'reflected', 'chain', 'interpretive', 'drop', 'instrumental', 'waiting', 'education', 'extensive', 'suitable', 'made', 'forward', 'either', 'northeast', 'outdoor', 'protected', 'thank', 'disambiguation', 'powered', 'rightly', 'barbados', 'city', 'sorry', 'reno', 'spawned', 'navigation', 'stanford', 'beach', 'air', 'take', 'vacation', 'user', 'held', 'utilitarian', 'street', 'foot', 'neighbourhood', 'send', 'delicious', 'antibiotic', 'startup', 'help', 'kid', 'registered', 'lighting', 'editing', 'visible', 'chang', 'hungary', 'galena', 'knoxville', 'boutique', 'vegetable', 'owned', 'ga', 'camp', 'marker', 'czech', 'want', 'landmark', 'rice', 'zen', 'authentic', 'bathed', 'might', 'monterey', 'maybe', 'healthy', 'dublin', 'stay', 'filter', 'force', 'order', 'packed', 'thing', 'traversed', 'wont', 'bay', 'watch', 'easy', 'connected', 'spend', 'quality', 'wondering', 'year', 'lunch', 'rouge', 'bozeman', 'tax', 'jogging', 'welcoming', 'department', 'brewery', 'classroom', 'pin', 'sleek', 'result', 'ira', 'gamble', 'precipitation', 'wayne', 'burberry', 'wurlitzer', 'philadelphia', 'wilmington', 'collector', 'rain', 'ed', 'indianapolis', 'vista', 'florence', 'cowper', 'ocean', 'booking', 'miami', 'manhattan', 'occasion', 'science', 'composition', 'lemon', 'salon', 'otherwise', 'historic', 'apple', 'taking', 'bruce', 'beautifully', 'club', 'information', 'fall', 'quebec', 'fe', 'convention', 'stage', 'jacksonville', 'explore', 'outside', 'augusta', 'license', 'slice', 'menu', 'vietnamese', 'data', 'retailer', 'comprising', 'poland', 'along', 'ph', 'levi', 'key', 'ireland', 'scottish', 'figure', 'wy', 'featuring', 'petal', 'eureka', 'show', 'included', 'kalamazoo', 'hill', 'spine', 'cave', 'variety', 'involved', 'tesla', 'program', 'established', 'carry', 'fireplace', 'zoo', 'symphony', 'contemporary', 'private', 'portuguese', 'toledo', 'fee', 'workshop', 'low', 'cantor', 'friday', 'came', 'business', 'burlington', 'adult', 'required', 'dancing', 'logged', 'valuable', 'turkey', 'heritage', 'soup', 'organist', 'chicago', 'reading', 'allied', 'challenge', 'nevis', 'article', 'pittsburgh', 'mumbai', 'jackson', 'medium', 'wellington', 'level', 'malta', 'housed', 'al', 'albany', 'arena', 'particle', 'ar', 'broadway', 'expensive', 'tad', 'pavilion', 'louis', 'item', 'soda', 'picture', 'hudson', 'cheery', 'patron', 'va', 'sitting', 'tomorrow', 'tomato', 'lighthouse', 'apr', 'crime', 'lisbon', 'avenue', 'seville', 'brown', 'almost', 'second', 'rib', 'expedition', 'tearoom', 'nasa', 'mediterranean', 'herbert', 'part', 'still', 'tucson', 'swimming', 'commonly', 'cheyenne', 'olive', 'jogger', 'fish', 'exiting', 'tourism', 'reserved', 'western', 'local', 'juneau', 'engineer', 'hedgehog', 'communicating', 'scotland', 'creative', 'princeton', 'dense', 'belgium', 'popular', 'must', 'civic', 'google', 'serra', 'rich', 'branch', 'tallahassee', 'springfield', 'ranging', 'burrito', 'wet', 'store', 'copenhagen', 'exposed', 'flower', 'concentrated', 'looking', 'ft', 'chasi ...

# %%
all_data = []
for each in news_data:
    all_data.append(clean_doc(each))
flat_list = [item for sublist in all_data for item in sublist]

# %%
# vectorize doc using tfidf vectorizer
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(tokens)
print("n_samples: %d, n_features: %d" % X.shape)
# Out:
# n_samples: 2190, n_features: 2105

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(stop_words='english')
X_vec = vect.fit_transform(dataset.data)
print("n_samples: %d, n_features: %d" % X_vec.shape)
# Out:
# n_samples: 3387, n_features: 43255

# %% [markdown]
# Performing dimension reduction using latent semantic analysis(LSA) as it works well with spacy sparce matrix and tfidf vector.

# %%
# Convert spacy sparce matrix to pandas dataframe
coo = X.tocoo(copy=False)
df = pd.DataFrame({'index': coo.row, 'col': coo.col, 'data': coo.data}
                 )[['index', 'col', 'data']].sort_values(['index', 'col']
                 ).reset_index(drop=True)
df.head()
# Out:
#    index    col  data
# 0      0  16950   1.0
# 1      1   4479   1.0
# 2      2  15327   1.0
# 3      3  17644   1.0
# 4      4  16481   1.0

# %%
print("Performing dimensionality reduction using LSA")

# Normalizing the data for best Kmean clustering performance
svd = TruncatedSVD()
normalizer = Normalizer(copy=False)
lsa = make_pipeline(svd, normalizer)

lsa_X = lsa.fit_transform(X)

# check variance
explained_variance = svd.explained_variance_ratio_.sum()
print("Explained variance of the SVD step: {}%".format(
    int(explained_variance * 100)))

print()


# #############################################################################
# Do the actual clustering    
def do_clustering(X, n_clust, need_model = False):
    km = MiniBatchKMeans(n_clusters=n_clust, init='k-means++', n_init=1, init_size=1000, batch_size=1000, verbose=1)
    #km = KMeans(n_clusters=n_clust, init='k-means++', max_iter=300, n_init=10)

    print("Clustering sparse data with %s" % km)

    km.fit(X)

    score = "%0.3f" % metrics.silhouette_score(X, km.labels_, sample_size=1000)
    print('Silhouette Coefficient: ',score)
    
    # return Silhouette score or model which ever is need by method
    if need_model is False:
        return float(score)
    else:
        return km

# getting best Silhouette score with that model
score_lst = []
for i in range(2, 8):
    score= do_clustering(lsa_X, i)
    score_lst.append(score)
get_max_score_index = score_lst.index(min(score_lst))
n_clust = get_max_score_index + 2

print('------------------------------------------------------------------')
print('Best Silhouette Coefficient score: {} with cluster number: {}'.format(min(score_lst), n_clust))
print('------------------------------------------------------------------')

# getting model and finding best cluster
km = do_clustering(lsa_X, n_clust, need_model = True)
print("Top terms per cluster:")
original_space_centroids = svd.inverse_transform(km.cluster_centers_)
order_centroids = original_space_centroids.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(n_clust):
    print("Cluster %d:" % i, end='')
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind], end='')
    print()
# Out:
# Performing dimensionality reduction using LSA
# Explained variance of the SVD step: 0%
#
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=2,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=1)
# Init 1/1 with method: k-means++
# Inertia for init 1/1: 587.800930
# Minibatch iteration 1/300: mean batch inertia: 0.575947, ewa inertia: 0.575947
# Minibatch iteration 2/300: mean batch inertia: 0.570472, ewa inertia: 0.570949
# Minibatch iteration 3/300: mean batch inertia: 0.566611, ewa inertia: 0.566989
# Minibatch iteration 4/300: mean batch inertia: 0.593639, ewa inertia: 0.591316
# Minibatch iteration 5/300: mean batch inertia: 0.594751, ewa inertia: 0.594452
# Minibatch iteration 6/300: mean batch inertia: 0.589957, ewa inertia: 0.590349
# Minibatch iteration 7/300: mean batch inertia: 0.593635, ewa inertia: 0.593348
# Minibatch iteration 8/300: mean batch inertia: 0.602186, ewa inertia: 0.601416
# Minibatch iteration 9/300: mean batch inertia: 0.597004, ewa inertia: 0.597389
# Minibatch iteration 10/300: mean batch inertia: 0.593450, ewa inertia: 0.593793
# Minibatch iteration 11/300: mean batch inertia: 0.597976, ewa inertia: 0.597612
# Minibatch iteration 12/300: mean batch inertia: 0.573698, ewa inertia: 0.575783
# Minibatch iteration 13/300: mean batch inertia: 0.586644, ewa inertia: 0.585698
# Converged (lack of improvement in inertia) at iteration 13/300
# Computing label assignment and total inertia
# Silhouette Coefficient:  0.398
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=3,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=1)
# Init 1/1 with method: k-means++
# Inertia for init 1/1: 340.860628
# Minibatch iteration 1/300: mean batch inertia: 0.332622, ewa inertia: 0.332622
# Minibatch iteration 2/300: mean batch inertia: 0.320023, ewa inertia: 0.321121
# Minibatch iteration 3/300: mean batch inertia: 0.335115, ewa inertia: 0.333895
# Minibatch iteration 4/300: mean batch inertia: 0.338813, ewa inertia: 0.338384
# Minibatch iteration 5/300: mean batch inertia: 0.337791, ewa inertia: 0.337842
# Minibatch iteration 6/300: mean batch inertia: 0.343572, ewa inertia: 0.343073
# Minibatch iteration 7/300: mean batch inertia: 0.327596, ewa inertia: 0.328945
# Minibatch iteration 8/300: mean batch inertia: 0.338328, ewa inertia: 0.337510
# Minibatch iteration 9/300: mean batch inertia: 0.333300, ewa inertia: 0.333667
# Minibatch iteration 10/300: mean batch inertia: 0.330381, ewa inertia: 0.330668
# Minibatch iteration 11/300: mean batch inertia: 0.325316, ewa inertia: 0.325782
# Minibatch iteration 12/300: mean batch inertia: 0.336250, ewa inertia: 0.335338
# Converged (lack of improvement in inertia) at iteration 12/300
# Computing label assignment and total inertia
# Silhouette Coefficient:  0.448
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=4,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=1)
# Init 1/1 with method: k-means++
# Inertia for init 1/1: 209.424394
# Minibatch iteration 1/300: mean batch inertia: 0.200579, ewa inertia: 0.200579
# Minibatch iteration 2/300: mean batch inertia: 0.198633, ewa inertia: 0.198803
# Minibatch iteration 3/300: mean batch inertia: 0.203710, ewa inertia: 0.203282
# Minibatch iteration 4/300: mean batch inertia: 0.209215, ewa inertia: 0.208698
# Minibatch iteration 5/300: mean batch inertia: 0.211950, ewa inertia: 0.211667
# Minibatch iteration 6/300: mean batch inertia: 0.216484, ewa inertia: 0.216064
# Minibatch iteration 7/300: mean batch inertia: 0.212722, ewa inertia: 0.213013
# Minibatch iteration 8/300: mean batch inertia: 0.208357, ewa inertia: 0.208763
# Minibatch iteration 9/300: mean batch inertia: 0.220320, ewa inertia: 0.219313
# Minibatch iteration 10/300: mean batch inertia: 0.206595, ewa inertia: 0.207704
# Minibatch iteration 11/300: mean batch inertia: 0.206799, ewa inertia: 0.206878
# Minibatch iteration 12/300: mean batch inertia: 0.215199, ewa inertia: 0.214474
# Converged (lack of improvement in inertia) at iteration 12/300
# Computing label assignment and total inertia
# Silhouette Coefficient:  0.473
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=5,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=1)
# Init 1/1 with method: k-means++
# Inertia for init 1/1: 145.279560
# Minibatch iteration 1/300: mean batch inertia: 0.156668, ewa inertia: 0.156668
# Minibatch iteration 2/300: mean batch inertia: 0.151473, ewa inertia: 0.151926
# Minibatch iteration 3/300: mean batch inertia: 0.144577, ewa inertia: 0.145218
# Minibatch iteration 4/300: mean batch inertia: 0.154076, ewa inertia: 0.153303
# Minibatch iteration 5/300: mean batch inertia: 0.152516, ewa inertia: 0.152584
# Minibatch iteration 6/300: mean batch inertia: 0.149751, ewa inertia: 0.149998
# Minibatch iteration 7/300: mean batch inertia: 0.155423, ewa inertia: 0.154950
# Minibatch iteration 8/300: mean batch inertia: 0.151538, ewa inertia: 0.151835
# Minibatch iteration 9/300: mean batch inertia: 0.149117, ewa inertia: 0.149354
# Minibatch iteration 10/300: mean batch inertia: 0.149866, ewa inertia: 0.149821
# Minibatch iteration 11/300: mean batch inertia: 0.148827, ewa inertia: 0.148913
# Minibatch iteration 12/300: mean batch inertia: 0.145750, ewa inertia: 0.146026
# Minibatch iteration 13/300: mean batch inertia: 0.146486, ewa inertia: 0.146446
# Converged (lack of improvement in inertia) at iteration 13/300
# Computing label assignment and total inertia
# Silhouette Coefficient:  0.474
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=6,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=1)
# Init 1/1 with method: k-means++
# Inertia for init 1/1: 111.809023
# Minibatch iteration 1/300: mean batch inertia: 0.110714, ewa inertia: 0.110714
# Minibatch iteration 2/300: mean batch inertia: 0.105608, ewa inertia: 0.106053
# Minibatch iteration 3/300: mean batch inertia: 0.114591, ewa inertia: 0.113847
# Minibatch iteration 4/300: mean batch inertia: 0.106229, ewa inertia: 0.106893
# Minibatch iteration 5/300: mean batch inertia: 0.107300, ewa inertia: 0.107265
# Minibatch iteration 6/300: mean batch inertia: 0.104282, ewa inertia: 0.104542
# Minibatch iteration 7/300: mean batch inertia: 0.112904, ewa inertia: 0.112175
# Minibatch iteration 8/300: mean batch inertia: 0.107852, ewa inertia: 0.108229
# Minibatch iteration 9/300: mean batch inertia: 0.108377, ewa inertia: 0.108364
# Minibatch iteration 10/300: mean batch inertia: 0.105196, ewa inertia: 0.105472
# Minibatch iteration 11/300: mean batch inertia: 0.110808, ewa inertia: 0.110343
# Minibatch iteration 12/300: mean batch inertia: 0.108168, ewa inertia: 0.108358
# Minibatch iteration 13/300: mean batch inertia: 0.108375, ewa inertia: 0.108373
# Minibatch iteration 14/300: mean batch inertia: 0.109455, ewa inertia: 0.109360
# Minibatch iteration 15/300: mean batch inertia: 0.112013, ewa inertia: 0.111782
# Minibatch iteration 16/300: mean batch inertia: 0.110957, ewa inertia: 0.111029
# Converged (lack of improvement in inertia) at iteration 16/300
# Computing label assignment and total inertia
# Silhouette Coefficient:  0.483
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=7,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=1)
# Init 1/1 with method: k-means++
# Inertia for init 1/1: 85.074318
# Minibatch iteration 1/300: mean batch inertia: 0.090351, ewa inertia: 0.090351
# Minibatch iteration 2/300: mean batch inertia: 0.088281, ewa inertia: 0.088461
# Minibatch iteration 3/300: mean batch inertia: 0.086798, ewa inertia: 0.086943
# Minibatch iteration 4/300: mean batch inertia: 0.083196, ewa inertia: 0.083522
# Minibatch iteration 5/300: mean batch inertia: 0.085433, ewa inertia: 0.085266
# Minibatch iteration 6/300: mean batch inertia: 0.084646, ewa inertia: 0.084700
# Minibatch iteration 7/300: mean batch inertia: 0.083398, ewa inertia: 0.083511
# Minibatch iteration 8/300: mean batch inertia: 0.083474, ewa inertia: 0.083478
# Minibatch iteration 9/300: mean batch inertia: 0.083033, ewa inertia: 0.083072
# Minibatch iteration 10/300: mean batch inertia: 0.087487, ewa inertia: 0.087102
# Minibatch iteration 11/300: mean batch inertia: 0.084864, ewa inertia: 0.085059
# Minibatch iteration 12/300: mean batch inertia: 0.080469, ewa inertia: 0.080869
# Minibatch iteration 13/300: mean batch inertia: 0.083167, ewa inertia: 0.082967
# Minibatch iteration 14/300: mean batch inertia: 0.083007, ewa inertia: 0.083004
# Minibatch iteration 15/300: mean batch inertia: 0.079794, ewa inertia: 0.080074
# Minibatch iteration 16/300: mean batch inertia: 0.089151, ewa inertia: 0.088360
# Minibatch iteration 17/300: mean batch inertia: 0.081438, ewa inertia: 0.082042
# Minibatch iteration 18/300: mean batch inertia: 0.081446, ewa inertia: 0.081498
# Minibatch iteration 19/300: mean batch inertia: 0.082152, ewa inertia: 0.082095
# Minibatch iteration 20/300: mean batch inertia: 0.082735, ewa inertia: 0.082679
# Minibatch iteration 21/300: mean batch inertia: 0.081798, ewa inertia: 0.081875
# Minibatch iteration 22/300: mean batch inertia: 0.081619, ewa inertia: 0.081642
# Minibatch iteration 23/300: mean batch inertia: 0.080442, ewa inertia: 0.080546
# Minibatch iteration 24/300: mean batch inertia: 0.082046, ewa inertia: 0.081915
# Minibatch iteration 25/300: mean batch inertia: 0.078747, ewa inertia: 0.079023
# Minibatch iteration 26/300: mean batch inertia: 0.082626, ewa inertia: 0.082312
# Minibatch iteration 27/300: mean batch inertia: 0.081745, ewa inertia: 0.081794
# Minibatch iteration 28/300: mean batch inertia: 0.083673, ewa inertia: 0.083509
# Minibatch iteration 29/300: mean batch inertia: 0.086401, ewa inertia: 0.086149
# Minibatch iteration 30/300: mean batch inertia: 0.085280, ewa inertia: 0.085356
# Minibatch iteration 31/300: mean batch inertia: 0.085263, ewa inertia: 0.085271
# Minibatch iteration 32/300: mean batch inertia: 0.081135, ewa inertia: 0.081496
# Minibatch iteration 33/300: mean batch inertia: 0.084469, ewa inertia: 0.084210
# Minibatch iteration 34/300: mean batch inertia: 0.087404, ewa inertia: 0.087125
# Minibatch iteration 35/300: mean batch inertia: 0.080887, ewa inertia: 0.081431
# Converged (lack of improvement in inertia) at iteration 35/300
# Computing label assignment and total inertia
# Silhouette Coefficient:  0.517
# ------------------------------------------------------------------
# Best Silhouette Coefficient score: 0.398 with cluster number: 2
# ------------------------------------------------------------------
# Clustering sparse data with MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=2,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=1)
# Init 1/1 with method: k-means++
# Inertia for init 1/1: 593.091348
# Minibatch iteration 1/300: mean batch inertia: 0.587552, ewa inertia: 0.587552
# Minibatch iteration 2/300: mean batch inertia: 0.580509, ewa inertia: 0.581123
# Minibatch iteration 3/300: mean batch inertia: 0.589028, ewa inertia: 0.588339
# Minibatch iteration 4/300: mean batch inertia: 0.579710, ewa inertia: 0.580462
# Minibatch iteration 5/300: mean batch inertia: 0.578219, ewa inertia: 0.578415
# Minibatch iteration 6/300: mean batch inertia: 0.593141, ewa inertia: 0.591857
# Minibatch iteration 7/300: mean batch inertia: 0.599086, ewa inertia: 0.598456
# Minibatch iteration 8/300: mean batch inertia: 0.587206, ewa inertia: 0.588187
# Minibatch iteration 9/300: mean batch inertia: 0.593485, ewa inertia: 0.593023
# Minibatch iteration 10/300: mean batch inertia: 0.569000, ewa inertia: 0.571094
# Minibatch iteration 11/300: mean batch inertia: 0.566602, ewa inertia: 0.566993
# Minibatch iteration 12/300: mean batch inertia: 0.576218, ewa inertia: 0.575414
# Minibatch iteration 13/300: mean batch inertia: 0.586543, ewa inertia: 0.585573
# Minibatch iteration 14/300: mean batch inertia: 0.591627, ewa inertia: 0.591100
# Minibatch iteration 15/300: mean batch inertia: 0.600504, ewa inertia: 0.599684
# Minibatch iteration 16/300: mean batch inertia: 0.569993, ewa inertia: 0.572582
# Minibatch iteration 17/300: mean batch inertia: 0.575266, ewa inertia: 0.575032
# Minibatch iteration 18/300: mean batch inertia: 0.592066, ewa inertia: 0.590581
# Minibatch iteration 19/300: mean batch inertia: 0.579130, ewa inertia: 0.580128
# Minibatch iteration 20/300: mean batch inertia: 0.574943, ewa inertia: 0.575395
# Minibatch iteration 21/300: mean batch inertia: 0.597383, ewa inertia: 0.595467
# Converged (lack of improvement in inertia) at iteration 21/300
# Computing label assignment and total inertia
# Silhouette Coefficient:  0.383
# Top terms per cluster:
# Cluster 0: scratch wale data aioli dense tasting manager tall served dinner
# Cluster 1: franklin richardson acre charge patrick grower orleans levi migratory id

# %% [markdown]
# As seen here, best Silhouette score is for 2 clusters. So, we will take cluster number as 2 for our KMeans model and will train the model. As seen in the above result, 1st cluster is talking about general place at Palo Alto, while 2nd cluster is talking about educational place. The result is little ambigious as scrapped data is less and not much organized and also we need to fine tuned the model in the next level.
